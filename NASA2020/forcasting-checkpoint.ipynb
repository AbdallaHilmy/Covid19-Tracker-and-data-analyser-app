# %%
import pandas as pd
# %matplotlib inline

# %%
data_url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
df = pd.read_csv(data_url)
df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  5/20/20  5/21/20  5/22/20  5/23/20  \
# 0        0        0        0  ...     8145     8676     9216     9998
# 1        0        0        0  ...      964      969      981      989
# 2        0        0        0  ...     7542     7728     7918     8113
# 3        0        0        0  ...      762      762      762      762
# 4        0        0        0  ...       52       58       60       61
#
#    5/24/20  5/25/20  5/26/20  5/27/20  5/28/20  5/29/20
# 0    10582    11173    11831    12456    13036    13659
# 1      998     1004     1029     1050     1076     1099
# 2     8306     8503     8697     8857     8997     9134
# 3      762      763      763      763      763      764
# 4       69       70       70       71       74       81
#
# [5 rows x 133 columns]

# %%
#filter using country name
df = df.loc[df['Country/Region'] == 'Egypt'] #change country name here

#remove unused columns
df.drop('Province/State', axis=1, inplace=True)
df.drop('Lat', axis=1, inplace=True)
df.drop('Long', axis=1, inplace=True)
df.head()
# Out:
#    Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 98          Egypt        0        0        0        0        0        0
#
#     1/28/20  1/29/20  1/30/20  ...  5/20/20  5/21/20  5/22/20  5/23/20  \
# 98        0        0        0  ...    14229    15003    15786    16513
#
#     5/24/20  5/25/20  5/26/20  5/27/20  5/28/20  5/29/20
# 98    17265    17967    18756    19666    20793    22082
#
# [1 rows x 130 columns]

# %%
df = df.groupby('Country/Region').sum()

#remove zero values
df = df.loc[:, (df != 0).any(axis=0)]

#remove the unused country column
df.reset_index(inplace=True)
df.drop('Country/Region', axis=1, inplace=True)
df.head()
# Out:
#    2/14/20  2/15/20  2/16/20  2/17/20  2/18/20  2/19/20  2/20/20  2/21/20  \
# 0        1        1        1        1        1        1        1        1
#
#    2/22/20  2/23/20  ...  5/20/20  5/21/20  5/22/20  5/23/20  5/24/20  \
# 0        1        1  ...    14229    15003    15786    16513    17265
#
#    5/25/20  5/26/20  5/27/20  5/28/20  5/29/20
# 0    17967    18756    19666    20793    22082
#
# [1 rows x 106 columns]

# %%
df = df.transpose()

#change to datetime
dformat = '%m/%d/%y'
df.index = pd.DatetimeIndex(pd.to_datetime(df.index, format=dformat))
df.head()
# Out:
#             0
# 2020-02-14  1
# 2020-02-15  1
# 2020-02-16  1
# 2020-02-17  1
# 2020-02-18  1

# %%
df.reset_index(inplace=True)
df.rename(columns={'index':'ds', 0:'y'},inplace=True)
df.head()
# Out:
#           ds  y
# 0 2020-02-14  1
# 1 2020-02-15  1
# 2 2020-02-16  1
# 3 2020-02-17  1
# 4 2020-02-18  1

# %%
ax = df.plot(x='ds', y='y',figsize=(12,6), title='Covid-19 daily cases')
ax.autoscale(axis='both',tight=True)
ax.set(xlabel='Date',ylabel='Cases');

# %%
from fbprophet import Prophet

#split data into training and test sets
train_to_index = round(len(df) * .95)
train_data = df.iloc[:train_to_index]
test_data = df.iloc[train_to_index:]

print('training data length',len(train_data),'test data length',len(test_data))
# Out:
# training data length 101 test data length 5

# %%
model = Prophet(growth ='linear',
seasonality_mode='multiplicative',
changepoint_prior_scale=0.5,
weekly_seasonality=False,
daily_seasonality=True)
model.fit(train_data)

#generate a dataframe with future dates, frequency is set to daily
future = model.make_future_dataframe(periods=len(test_data),freq='D')

#predict values for future dates
forecast = model.predict(future)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
model.plot(forecast);

# %%
metric_df = forecast.set_index('ds')[['yhat']].join(df.set_index('ds').y).reset_index()
metric_df.tail()
# Out:
#             ds          yhat      y
# 101 2020-05-25  16726.766360  17967
# 102 2020-05-26  17214.457813  18756
# 103 2020-05-27  17702.149266  19666
# 104 2020-05-28  18189.840719  20793
# 105 2020-05-29  18677.532172  22082

# %%
from sklearn.metrics import r2_score

r2_score(metric_df.y, metric_df.yhat)
# Out:
# 0.990948858125254

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(metric_df.y, metric_df.yhat)
# Out:
# 290390.0452047712

# %%
future = model.make_future_dataframe(periods=10, freq = 'D')

#predict values for future dates
forecast = model.predict(future)

#print only required columns ds, yhat, yhat_lower, yhat_upper
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(10)
# Out:
#             ds          yhat    yhat_lower    yhat_upper
# 101 2020-05-25  16726.766360  16471.592015  16972.153826
# 102 2020-05-26  17214.457813  16929.952046  17492.416523
# 103 2020-05-27  17702.149266  17413.884307  18001.301271
# 104 2020-05-28  18189.840719  17890.973594  18471.243736
# 105 2020-05-29  18677.532172  18380.045042  18984.077586
# 106 2020-05-30  19165.223625  18831.167573  19469.016348
# 107 2020-05-31  19652.915079  19307.436307  20009.399190
# 108 2020-06-01  20140.606532  19719.268392  20498.039479
# 109 2020-06-02  20628.297985  20199.043193  21023.427423
# 110 2020-06-03  21115.989438  20618.822283  21567.573262
