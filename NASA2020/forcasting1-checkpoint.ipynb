# %%
import pandas as pd
# %matplotlib inline

# %%
data = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
df = pd.read_csv(data)
df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  5/19/20  5/20/20  5/21/20  5/22/20  \
# 0        0        0        0  ...     7653     8145     8676     9216
# 1        0        0        0  ...      949      964      969      981
# 2        0        0        0  ...     7377     7542     7728     7918
# 3        0        0        0  ...      761      762      762      762
# 4        0        0        0  ...       52       52       58       60
#
#    5/23/20  5/24/20  5/25/20  5/26/20  5/27/20  5/28/20
# 0     9998    10582    11173    11831    12456    13036
# 1      989      998     1004     1029     1050     1076
# 2     8113     8306     8503     8697     8857     8997
# 3      762      762      763      763      763      763
# 4       61       69       70       70       71       74
#
# [5 rows x 132 columns]

# %%
df = df.loc[df['Country/Region'] == 'Egypt'] #change country name here

#remove unused columns
df.drop('Province/State', axis=1, inplace=True)
df.drop('Lat', axis=1, inplace=True)
df.drop('Long', axis=1, inplace=True)
df.head()
# Out:
#    Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 98          Egypt        0        0        0        0        0        0
#
#     1/28/20  1/29/20  1/30/20  ...  5/19/20  5/20/20  5/21/20  5/22/20  \
# 98        0        0        0  ...    13484    14229    15003    15786
#
#     5/23/20  5/24/20  5/25/20  5/26/20  5/27/20  5/28/20
# 98    16513    17265    17967    18756    19666    20793
#
# [1 rows x 129 columns]

# %%
#group all rows of same country
df = df.groupby('Country/Region').sum()

#remove zero values
df = df.loc[:, (df != 0).any(axis=0)]

#remove the unused country column
df.reset_index(inplace=True)
df.drop('Country/Region', axis=1, inplace=True)
df.head()
# Out:
#    2/14/20  2/15/20  2/16/20  2/17/20  2/18/20  2/19/20  2/20/20  2/21/20  \
# 0        1        1        1        1        1        1        1        1
#
#    2/22/20  2/23/20  ...  5/19/20  5/20/20  5/21/20  5/22/20  5/23/20  \
# 0        1        1  ...    13484    14229    15003    15786    16513
#
#    5/24/20  5/25/20  5/26/20  5/27/20  5/28/20
# 0    17265    17967    18756    19666    20793
#
# [1 rows x 105 columns]

# %%
#transpose the matrix to create a row for each date entry
df = df.transpose()

#change to datetime
dformat = '%m/%d/%y'
df.index = pd.DatetimeIndex(pd.to_datetime(df.index, format=dformat))
df.head()
# Out:
#             0
# 2020-02-14  1
# 2020-02-15  1
# 2020-02-16  1
# 2020-02-17  1
# 2020-02-18  1

# %%
df.reset_index(inplace=True)
df.rename(columns={'index':'ds', 0:'y'},inplace=True)
df.head()
# Out:
#           ds  y
# 0 2020-02-14  1
# 1 2020-02-15  1
# 2 2020-02-16  1
# 3 2020-02-17  1
# 4 2020-02-18  1

# %%
ax = df.plot(x='ds', y='y',figsize=(12,6), title='Covid-19 daily cases')
ax.autoscale(axis='both',tight=True)
ax.set(xlabel='Date',ylabel='Cases');

# %%
from fbprophet import Prophet

#split data into training and test sets
train_to_index = round(len(df) * .95)
train_data = df.iloc[:train_to_index]
test_data = df.iloc[train_to_index:]

print('training data length',len(train_data),'test data length',len(test_data))
# Out:
# training data length 100 test data length 5

# %%
#create model and train on training set
model = Prophet(growth ='linear',
seasonality_mode='multiplicative',
changepoint_prior_scale=0.5,
weekly_seasonality=False,
daily_seasonality=True)
model.fit(train_data)

#generate a dataframe with future dates, frequency is set to daily
future = model.make_future_dataframe(periods=len(test_data),freq='D')

#predict values for future dates
forecast = model.predict(future)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
model.plot(forecast);

# %%
metric_df = forecast.set_index('ds')[['yhat']].join(df.set_index('ds').y).reset_index()
metric_df.tail()
# Out:
#             ds          yhat      y
# 100 2020-05-24  16036.748085  17265
# 101 2020-05-25  16510.833418  17967
# 102 2020-05-26  16984.918750  18756
# 103 2020-05-27  17459.004083  19666
# 104 2020-05-28  17933.089416  20793

# %%
from sklearn.metrics import r2_score

r2_score(metric_df.y, metric_df.yhat)
# Out:
# 0.9924587244021463

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(metric_df.y, metric_df.yhat)
# Out:
# 221090.08866458153

# %%
#generate a dataframe with future dates, frequency is set to daily
future = model.make_future_dataframe(periods=17, freq = 'D')

#predict values for future dates
forecast = model.predict(future)

#print only required columns ds, yhat, yhat_lower, yhat_upper
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(10)
# Out:
#             ds          yhat    yhat_lower    yhat_upper
# 107 2020-05-31  19355.345414  18988.206388  19704.524176
# 108 2020-06-01  19829.430746  19426.552065  20213.619746
# 109 2020-06-02  20303.516079  19850.051391  20734.044512
# 110 2020-06-03  20777.601412  20278.465643  21269.875322
# 111 2020-06-04  21251.686745  20676.250856  21794.168327
# 112 2020-06-05  21725.772077  21082.491283  22308.717489
# 113 2020-06-06  22199.857410  21541.616185  22873.517143
# 114 2020-06-07  22673.942743  21949.618045  23374.149308
# 115 2020-06-08  23148.028075  22306.491827  23907.982163
# 116 2020-06-09  23622.113408  22711.283294  24528.114565
